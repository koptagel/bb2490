# %%
# %%writefile search_script.py

import time
import os
import argparse

def main():
    # code to process command line arguments
    parser = argparse.ArgumentParser(description='Peptide Search.')
    parser.add_argument('ph_range', help="Specify the ph range (\"acidic\" for 2.5-3.7, \"wide\" for 3-10).", type=str)
    parser.add_argument('sample_range_min', help="Specify which samples to use (min index, included).", type=int)
    parser.add_argument('sample_range_max', help="Specify which samples to use (max index, not included).", type=int)
    
    # For crux
    parser.add_argument('--crux_bin_path', help="Specify the location of crux's bin folder.", type=str, default="../crux-3.2.Darwin.x86_64/bin/")
    
    # For tide-index
    parser.add_argument('--fasta_dir', help="Specify the location and name of fasta file.", type=str, default="../data/swissprot_human_can-iso_20170206.fasta")
    parser.add_argument('--out_ref_index_dir', help="Specify the reference index directory.", type=str, default="../results/ref-index")
    parser.add_argument('--out_index_dir', help="Specify the output index directory.", type=str, default="../results/index_output")
    parser.add_argument('--max_mods', help="Specify the maximum number of modifications.", type=int, default=4)
    parser.add_argument('--mods_spec', help="Specify the modification specifications.", type=str, default="1STY+79.966, 1M+15.995, C+57.021, K+229.162932")
    parser.add_argument('--nterm_peptide_mods_spec', help="Specify the n-terminus modification specifications.", type=str, default="X+229.162932")
    
    # For tide-search
    parser.add_argument('--ms_dir', help="Specify the location of ms2 files.", type=str, default="../data/ms2_data/")
    parser.add_argument('--out_search_dir', help="Specify the output search directory.", type=str, default="../results/")
    
    # For percolator
    parser.add_argument('--fdr', help="Specify the test FDR.", type=float, default=0.01)
    
    args = parser.parse_args()
    
    start_time_global = time.time()
    print("Arguments are loaded...")
    
    # Add crux path
    job_name = "path"
    
    print("\nRunning ", job_name)
    start_mini_time = time.time()
    #path = "../crux-3.2.Darwin.x86_64/bin/"
    os.environ['PATH'] += ':' + args.crux_bin_path
    cmd = "echo $PATH"
    os.system(cmd)
    print(os.system(cmd))
    end_mini_time = time.time()
    print("Finished ", job_name)
    print("Runtime: ", end_mini_time-start_mini_time)
    
    # Run tide-index
    job_name = "tide-index"
    cmd = "crux tide-index " + args.fasta_dir + " " + args.out_ref_index_dir + " " + " --output-dir \"" + args.out_index_dir + "\" --max-mods " + str(args.max_mods) + " --mods-spec \"" + args.mods_spec + "\" --nterm-peptide-mods-spec \"" + args.nterm_peptide_mods_spec +"\""
    print("\nRunning ", job_name)
    print(cmd)
    start_mini_time = time.time()
    os.system(cmd)
    end_mini_time = time.time()
    print("Finished ", job_name)
    print("Runtime: ", end_mini_time-start_mini_time)
    
    
    for idx in range(args.sample_range_min, args.sample_range_max):
        start_sample_time = time.time()
        
        str_idx = str(idx)
        if idx < 10:
            str_idx = "0" + str_idx
            
        if args.ph_range == "acidic" and idx > 72:
            print("\n***Exceeded the limit.")
            break
        if args.ph_range == "wide" and idx > 60:
            print("\n***Exceeded the limit.")
            break  
        
        if args.ph_range == "acidic":
            sample_filename = "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr" + str_idx
        else: # "wide"
            sample_filename = "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr" + str_idx
            
        print("\n***Running for sample: ", sample_filename)

        # Run tide-search
        job_name = "tide-search"

        ms2_filename = args.ms_dir + sample_filename + ".ms2"
        out_foldername = args.out_search_dir + "out_" + sample_filename
        
        #ms2_filename = args.ms_dir + "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr01.ms2"
        #out_foldername = args.out_search_dir + "out_" + "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr01"
        cmd = "crux tide-search --compute-sp T " + ms2_filename + " " + args.out_ref_index_dir + " " + " --output-dir \"" + out_foldername + "\""
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/tide-search.target.txt"
        out_filename = out_foldername + "/tide-search.target.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"xcorr score\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run percolator
        job_name = "percolator"

        cmd = "crux percolator --test-fdr " + str(args.fdr) + " --train-fdr " + str(args.fdr) + " " + in_filename + " --output-dir \"" + out_foldername + "\""
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)
        
        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.peptides.txt"
        out_filename = out_foldername + "/percolator.target.peptides.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)
        
        # Run sort-by-column_2
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.peptides.txt"
        out_filename = "../results/all_results/" + sample_filename + "_percolator.target.peptides.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.psms.txt"
        out_filename = out_foldername + "/percolator.target.psms.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator score\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column_2
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.psms.txt"
        out_filename = "../results/all_results/" + sample_filename + "_percolator.target.psms.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator score\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        
        end_sample_time = time.time()
        print("\n\tRuntime of sample: ", end_sample_time-start_sample_time)

    end_time_global = time.time()
    print("\nTotal runtime: ", end_time_global-start_time_global)

    
if __name__ == "__main__":
    main()

# %%
#%run search_script.py "wide" 1 61
#%run search_script.py "acidic" 1 73

#%run search_script.py "wide" 1 61 --ms_dir="/Volumes/WD/bb2490_data/" --fdr=0.05
# %run search_script.py "wide" 33 61 --fdr=0.05
# Out:
# Arguments are loaded...
#
# Running  path
# 0
# Finished  path
# Runtime:  0.0049130916595458984
#
# Running  tide-index
# crux tide-index ../data/swissprot_human_can-iso_20170206.fasta ../results/ref-index  --output-dir "../results/index_output" --max-mods 4 --mods-spec "1STY+79.966, 1M+15.995, C+57.021, K+229.162932" --nterm-peptide-mods-spec "X+229.162932"
# Finished  tide-index
# Runtime:  0.015259027481079102
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33"
# 	Finished  tide-search
# 	Runtime:  34.791402101516724
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.923825979232788
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33"
# 	Finished  percolator
# 	Runtime:  82.79454803466797
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08817601203918457
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0921778678894043
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.1051020622253418
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr33_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10845780372619629
#
# 	Runtime of sample:  119.90692019462585
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34"
# 	Finished  tide-search
# 	Runtime:  42.30454206466675
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  2.5031352043151855
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34"
# 	Finished  percolator
# 	Runtime:  77.9164731502533
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0874028205871582
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09246587753295898
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10889101028442383
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr34_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.12026000022888184
#
# 	Runtime of sample:  123.13676714897156
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35"
# 	Finished  tide-search
# 	Runtime:  39.115939140319824
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  2.7854650020599365
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35"
# 	Finished  percolator
# 	Runtime:  73.49728488922119
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.1180870532989502
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.17674899101257324
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.2459719181060791
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr35_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.22240400314331055
#
# 	Runtime of sample:  116.16674184799194
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36"
# 	Finished  tide-search
# 	Runtime:  36.286892890930176
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.9163250923156738
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36"
# 	Finished  percolator
# 	Runtime:  71.68178296089172
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.15201306343078613
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.14876699447631836
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10052204132080078
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr36_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0936441421508789
#
# 	Runtime of sample:  110.38471007347107
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37"
# 	Finished  tide-search
# 	Runtime:  32.19246506690979
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.7920410633087158
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37"
# 	Finished  percolator
# 	Runtime:  75.37668013572693
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08933401107788086
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09414410591125488
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10069394111633301
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr37_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10470986366271973
#
# 	Runtime of sample:  109.75319385528564
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr38
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr38.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55"
# 	Finished  percolator
# 	Runtime:  44.27791905403137
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10804080963134766
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0879828929901123
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09558391571044922
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0922398567199707
#
# 	Runtime of sample:  63.82356810569763
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56"
# 	Finished  tide-search
# 	Runtime:  16.891860008239746
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.4068868160247803
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56"
# 	Finished  percolator
# 	Runtime:  49.13123798370361
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07855701446533203
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08489394187927246
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09270405769348145
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08650708198547363
#
# 	Runtime of sample:  67.77607202529907
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57"
# 	Finished  tide-search
# 	Runtime:  15.317010879516602
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.283937931060791
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57"
# 	Finished  percolator
# 	Runtime:  35.867939949035645
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08899188041687012
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0916450023651123
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0906379222869873
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09375882148742676
#
# 	Runtime of sample:  52.83781695365906
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58"
# 	Finished  tide-search
# 	Runtime:  16.521952152252197
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.35371994972229
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58"
# 	Finished  percolator
# 	Runtime:  60.214804887771606
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.1104121208190918
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.1326150894165039
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10490798950195312
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.11271309852600098
#
# 	Runtime of sample:  78.55491995811462
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59"
# 	Finished  tide-search
# 	Runtime:  8.134557962417603
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.6671810150146484
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59"
# 	Finished  percolator
# 	Runtime:  30.354873180389404
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06681704521179199
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05386710166931152
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05484509468078613
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.059493064880371094
#
# 	Runtime of sample:  39.39676213264465
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60"
# 	Finished  tide-search
# 	Runtime:  5.0844950675964355
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5094330310821533
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60"
# 	Finished  percolator
# 	Runtime:  32.23825979232788
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03715395927429199
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03866004943847656
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04492306709289551
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04136013984680176
#
# 	Runtime of sample:  37.99703001976013
#
# Total runtime:  2649.9928641319275

# %%
#%run search_script.py "acidic" 1 73 --ms_dir="/Volumes/WD/bb2490_data/" --fdr=0.05
# %run search_script.py "acidic" 7 8 --fdr=0.05
# Out:
# Arguments are loaded...
#
# Running  path
# 0
# Finished  path
# Runtime:  0.004530906677246094
#
# Running  tide-index
# crux tide-index ../data/swissprot_human_can-iso_20170206.fasta ../results/ref-index  --output-dir "../results/index_output" --max-mods 4 --mods-spec "1STY+79.966, 1M+15.995, C+57.021, K+229.162932" --nterm-peptide-mods-spec "X+229.162932"
# Finished  tide-index
# Runtime:  0.012804031372070312
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07"
# 	Finished  tide-search
# 	Runtime:  17.860440969467163
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.750209093093872
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07"
# 	Finished  percolator
# 	Runtime:  59.33847093582153
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09326696395874023
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09598493576049805
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.psms.txt "percolator score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10290718078613281
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07/percolator.target.psms.txt "percolator score" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr07_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.12047505378723145
#
# 	Runtime of sample:  79.36604189872742
#
# Total runtime:  79.3835380077362
