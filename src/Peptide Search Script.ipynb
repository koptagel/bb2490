# %%
# %%writefile search_script.py

import time
import os
import argparse

def main():
    # code to process command line arguments
    parser = argparse.ArgumentParser(description='Peptide Search.')
    parser.add_argument('ph_range', help="Specify the ph range (\"acidic\" for 2.5-3.7, \"wide\" for 3-10).", type=str)
    parser.add_argument('sample_range_min', help="Specify which samples to use (min index, included).", type=int)
    parser.add_argument('sample_range_max', help="Specify which samples to use (max index, not included).", type=int)
    
    # For crux
    parser.add_argument('--crux_bin_path', help="Specify the location of crux's bin folder.", type=str, default="../crux-3.2.Darwin.x86_64/bin/")
    
    # For tide-index
    parser.add_argument('--fasta_dir', help="Specify the location and name of fasta file.", type=str, default="../data/swissprot_human_can-iso_20170206.fasta")
    parser.add_argument('--out_ref_index_dir', help="Specify the reference index directory.", type=str, default="../results/ref-index")
    parser.add_argument('--out_index_dir', help="Specify the output index directory.", type=str, default="../results/index_output")
    parser.add_argument('--max_mods', help="Specify the maximum number of modifications.", type=int, default=4)
    parser.add_argument('--mods_spec', help="Specify the modification specifications.", type=str, default="1STY+79.966, 1M+15.995, C+57.021, K+229.162932")
    parser.add_argument('--nterm_peptide_mods_spec', help="Specify the n-terminus modification specifications.", type=str, default="X+229.162932")
    
    # For tide-search
    parser.add_argument('--ms_dir', help="Specify the location of ms2 files.", type=str, default="../data/ms2_data/")
    parser.add_argument('--out_search_dir', help="Specify the output search directory.", type=str, default="../results/")
    
    # For percolator
    parser.add_argument('--fdr', help="Specify the test FDR.", type=float, default=0.01)
    
    args = parser.parse_args()
    
    start_time_global = time.time()
    print("Arguments are loaded...")
    
    # Add crux path
    job_name = "path"
    
    print("\nRunning ", job_name)
    start_mini_time = time.time()
    #path = "../crux-3.2.Darwin.x86_64/bin/"
    os.environ['PATH'] += ':' + args.crux_bin_path
    cmd = "echo $PATH"
    os.system(cmd)
    print(os.system(cmd))
    end_mini_time = time.time()
    print("Finished ", job_name)
    print("Runtime: ", end_mini_time-start_mini_time)
    
    # Run tide-index
    job_name = "tide-index"
    cmd = "crux tide-index " + args.fasta_dir + " " + args.out_ref_index_dir + " " + " --output-dir \"" + args.out_index_dir + "\" --max-mods " + str(args.max_mods) + " --mods-spec \"" + args.mods_spec + "\" --nterm-peptide-mods-spec \"" + args.nterm_peptide_mods_spec +"\""
    print("\nRunning ", job_name)
    print(cmd)
    start_mini_time = time.time()
    os.system(cmd)
    end_mini_time = time.time()
    print("Finished ", job_name)
    print("Runtime: ", end_mini_time-start_mini_time)
    
    
    for idx in range(args.sample_range_min, args.sample_range_max):
        start_sample_time = time.time()
        
        str_idx = str(idx)
        if idx < 10:
            str_idx = "0" + str_idx
            
        if args.ph_range == "acidic" and idx > 72:
            print("\n***Exceeded the limit.")
            break
        if args.ph_range == "wide" and idx > 60:
            print("\n***Exceeded the limit.")
            break  
        
        if args.ph_range == "acidic":
            sample_filename = "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr" + str_idx
        else: # "wide"
            sample_filename = "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr" + str_idx
            
        print("\n***Running for sample: ", sample_filename)

        # Run tide-search
        job_name = "tide-search"

        ms2_filename = args.ms_dir + sample_filename + ".ms2"
        out_foldername = args.out_search_dir + "out_" + sample_filename
        
        #ms2_filename = args.ms_dir + "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr01.ms2"
        #out_foldername = args.out_search_dir + "out_" + "ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr01"
        #cmd = "crux tide-search --compute-sp T " + ms2_filename + " " + args.out_ref_index_dir + " " + " --output-dir \"" + out_foldername + "\""
        cmd = "crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm " + ms2_filename + " " + args.out_ref_index_dir + " " + " --output-dir \"" + out_foldername + "\""
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/tide-search.target.txt"
        out_filename = out_foldername + "/tide-search.target.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"xcorr score\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run percolator
        job_name = "percolator"

        cmd = "crux percolator --test-fdr " + str(args.fdr) + " --train-fdr " + str(args.fdr) + " " + in_filename + " --output-dir \"" + out_foldername + "\""
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)
        
        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.peptides.txt"
        out_filename = out_foldername + "/percolator.target.peptides.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)
        
        # Run sort-by-column_2
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.peptides.txt"
        out_filename = "../results/all_results/" + sample_filename + "_percolator.target.peptides.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.psms.txt"
        out_filename = out_foldername + "/percolator.target.psms.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        # Run sort-by-column_2
        job_name = "sort-by-column"

        in_filename = out_foldername + "/percolator.target.psms.txt"
        out_filename = "../results/all_results/" + sample_filename + "_percolator.target.psms.sort.txt"
        cmd = "crux sort-by-column --column-type real --ascending T " + in_filename + " \"percolator q-value\" > " + out_filename
        print("\n\tRunning ", job_name)
        print("\t", cmd)
        start_mini_time = time.time()
        os.system(cmd)
        end_mini_time = time.time()
        print("\tFinished ", job_name)
        print("\tRuntime: ", end_mini_time-start_mini_time)

        
        end_sample_time = time.time()
        print("\n\tRuntime of sample: ", end_sample_time-start_sample_time)

    end_time_global = time.time()
    print("\nTotal runtime: ", end_time_global-start_time_global)

    
if __name__ == "__main__":
    main()
# Out:
# Overwriting search_script.py

# %%
#%run search_script.py "wide" 1 61
#%run search_script.py "acidic" 1 73

#%run search_script.py "wide" 1 61 --ms_dir="/Volumes/WD/bb2490_data/" --fdr=0.05
# %run search_script.py "wide" 50 61 --fdr=0.05
# Out:
# Arguments are loaded...
#
# Running  path
# 0
# Finished  path
# Runtime:  0.005186796188354492
#
# Running  tide-index
# crux tide-index ../data/swissprot_human_can-iso_20170206.fasta ../results/ref-index  --output-dir "../results/index_output" --max-mods 4 --mods-spec "1STY+79.966, 1M+15.995, C+57.021, K+229.162932" --nterm-peptide-mods-spec "X+229.162932"
# Finished  tide-index
# Runtime:  0.014654159545898438
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50"
# 	Finished  tide-search
# 	Runtime:  25.51072406768799
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.9868619441986084
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50"
# 	Finished  percolator
# 	Runtime:  41.92519998550415
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06845521926879883
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06622910499572754
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07235503196716309
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr50_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08036112785339355
#
# 	Runtime of sample:  68.71317100524902
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51"
# 	Finished  tide-search
# 	Runtime:  22.000587940216064
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8526849746704102
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51"
# 	Finished  percolator
# 	Runtime:  38.577728033065796
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0694580078125
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06916999816894531
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10921406745910645
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr51_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07574987411499023
#
# 	Runtime of sample:  61.75781607627869
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52"
# 	Finished  tide-search
# 	Runtime:  17.88895583152771
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8079469203948975
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52"
# 	Finished  percolator
# 	Runtime:  45.05749988555908
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.052822113037109375
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10642480850219727
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.17781591415405273
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr52_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07517099380493164
#
# 	Runtime of sample:  64.17073702812195
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53"
# 	Finished  tide-search
# 	Runtime:  17.0265109539032
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8019609451293945
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53"
# 	Finished  percolator
# 	Runtime:  43.327378034591675
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.053193092346191406
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.053405046463012695
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06089591979980469
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr53_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06113600730895996
#
# 	Runtime of sample:  61.387491941452026
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54"
# 	Finished  tide-search
# 	Runtime:  14.767735004425049
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.815436840057373
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54"
# 	Finished  percolator
# 	Runtime:  36.261138916015625
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0698859691619873
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07302999496459961
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07583999633789062
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr54_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08548784255981445
#
# 	Runtime of sample:  52.1518030166626
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55"
# 	Finished  tide-search
# 	Runtime:  13.082714080810547
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5369529724121094
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55"
# 	Finished  percolator
# 	Runtime:  30.738774061203003
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0583338737487793
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06594514846801758
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0723118782043457
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr55_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.10805201530456543
#
# 	Runtime of sample:  44.66665697097778
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56"
# 	Finished  tide-search
# 	Runtime:  12.672886848449707
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.54640793800354
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56"
# 	Finished  percolator
# 	Runtime:  122.98855900764465
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09275317192077637
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08385396003723145
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07263898849487305
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr56_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06824994087219238
#
# 	Runtime of sample:  136.52920484542847
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57"
# 	Finished  tide-search
# 	Runtime:  15.159238815307617
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8520431518554688
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57"
# 	Finished  percolator
# 	Runtime:  98.11140489578247
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.1332550048828125
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0656881332397461
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0716860294342041
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr57_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07291293144226074
#
# 	Runtime of sample:  114.4700927734375
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58"
# 	Finished  tide-search
# 	Runtime:  15.952789068222046
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.4961719512939453
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58"
# 	Finished  percolator
# 	Runtime:  15.537089109420776
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0557858943939209
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07232499122619629
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.055194854736328125
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr58_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05328798294067383
#
# 	Runtime of sample:  32.22645092010498
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59"
# 	Finished  tide-search
# 	Runtime:  6.051349878311157
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.23432588577270508
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59"
# 	Finished  percolator
# 	Runtime:  57.04075789451599
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04506397247314453
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03094792366027832
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.035379886627197266
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr59_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.046957969665527344
#
# 	Runtime of sample:  63.48850417137146
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60"
# 	Finished  tide-search
# 	Runtime:  3.431497097015381
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.2341139316558838
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60"
# 	Finished  percolator
# 	Runtime:  39.81513690948486
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03409099578857422
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.025174856185913086
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.02924799919128418
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG3-10_10of15ul_fr60_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.02730107307434082
#
# 	Runtime of sample:  43.59965515136719
#
# Total runtime:  743.1817700862885

# %%
#%run search_script.py "acidic" 1 73 --ms_dir="/Volumes/WD/bb2490_data/" --fdr=0.05
# %run search_script.py "acidic" 30 73 --fdr=0.05
# Out:
# Arguments are loaded...
#
# Running  path
# 0
# Finished  path
# Runtime:  0.005803108215332031
#
# Running  tide-index
# crux tide-index ../data/swissprot_human_can-iso_20170206.fasta ../results/ref-index  --output-dir "../results/index_output" --max-mods 4 --mods-spec "1STY+79.966, 1M+15.995, C+57.021, K+229.162932" --nterm-peptide-mods-spec "X+229.162932"
# Finished  tide-index
# Runtime:  0.014404058456420898
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30"
# 	Finished  tide-search
# 	Runtime:  18.415876865386963
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5586729049682617
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30"
# 	Finished  percolator
# 	Runtime:  26.656291007995605
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.052246809005737305
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05051898956298828
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05479288101196289
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr30_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05321907997131348
#
# 	Runtime of sample:  45.84464502334595
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31"
# 	Finished  tide-search
# 	Runtime:  17.60492992401123
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.47448205947875977
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31"
# 	Finished  percolator
# 	Runtime:  52.566519021987915
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.049566030502319336
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04262995719909668
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04955005645751953
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr31_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.044793128967285156
#
# 	Runtime of sample:  70.83463501930237
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32"
# 	Finished  tide-search
# 	Runtime:  19.91822600364685
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5176279544830322
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32"
# 	Finished  percolator
# 	Runtime:  26.748613119125366
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04775500297546387
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.046319007873535156
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.054926156997680664
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr32_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05311298370361328
#
# 	Runtime of sample:  47.38904595375061
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33"
# 	Finished  tide-search
# 	Runtime:  21.039931058883667
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5746769905090332
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33"
# 	Finished  percolator
# 	Runtime:  23.12855815887451
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05628085136413574
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06055498123168945
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06016397476196289
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr33_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05842399597167969
#
# 	Runtime of sample:  44.98221516609192
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34"
# 	Finished  tide-search
# 	Runtime:  27.34853506088257
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.6533010005950928
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34"
# 	Finished  percolator
# 	Runtime:  32.391794204711914
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05431795120239258
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06844806671142578
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06504607200622559
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr34_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0597379207611084
#
# 	Runtime of sample:  60.64415788650513
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35"
# 	Finished  tide-search
# 	Runtime:  21.49117422103882
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5736241340637207
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35"
# 	Finished  percolator
# 	Runtime:  33.297842025756836
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04200005531311035
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05170297622680664
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06282496452331543
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr35_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06129789352416992
#
# 	Runtime of sample:  55.58374500274658
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36"
# 	Finished  tide-search
# 	Runtime:  24.8963680267334
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.621690034866333
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36"
# 	Finished  percolator
# 	Runtime:  37.24842190742493
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.051680803298950195
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06685590744018555
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07887697219848633
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr36_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0728139877319336
#
# 	Runtime of sample:  63.04022693634033
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37"
# 	Finished  tide-search
# 	Runtime:  21.786617040634155
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5097789764404297
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37"
# 	Finished  percolator
# 	Runtime:  21.245532989501953
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.045301198959350586
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0516200065612793
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.052522897720336914
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr37_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05535101890563965
#
# 	Runtime of sample:  43.7493360042572
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38"
# 	Finished  tide-search
# 	Runtime:  22.155000925064087
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.4854469299316406
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38"
# 	Finished  percolator
# 	Runtime:  27.585242986679077
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.038836002349853516
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04447293281555176
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05848217010498047
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr38_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05298781394958496
#
# 	Runtime of sample:  50.42328500747681
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39"
# 	Finished  tide-search
# 	Runtime:  21.14205312728882
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.45406603813171387
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39"
# 	Finished  percolator
# 	Runtime:  173.10257482528687
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03673100471496582
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04150390625
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05372905731201172
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr39_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04444098472595215
#
# 	Runtime of sample:  194.8774609565735
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40"
# 	Finished  tide-search
# 	Runtime:  25.3527889251709
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5657269954681396
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40"
# 	Finished  percolator
# 	Runtime:  22.127593994140625
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04354596138000488
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.052262067794799805
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.055943965911865234
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr40_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05001401901245117
#
# 	Runtime of sample:  48.25049185752869
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41"
# 	Finished  tide-search
# 	Runtime:  29.937103033065796
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.6365840435028076
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41"
# 	Finished  percolator
# 	Runtime:  19.482468128204346
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.044850826263427734
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05230903625488281
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05699300765991211
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr41_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.050898075103759766
#
# 	Runtime of sample:  50.26365900039673
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42"
# 	Finished  tide-search
# 	Runtime:  21.95662498474121
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.4804110527038574
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42"
# 	Finished  percolator
# 	Runtime:  26.23505401611328
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03766298294067383
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03799796104431152
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0648198127746582
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr42_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04688286781311035
#
# 	Runtime of sample:  48.86178517341614
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43"
# 	Finished  tide-search
# 	Runtime:  22.964744806289673
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5049231052398682
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43"
# 	Finished  percolator
# 	Runtime:  29.590260982513428
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04198598861694336
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04126596450805664
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06657814979553223
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr43_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.048959970474243164
#
# 	Runtime of sample:  53.260939836502075
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44"
# 	Finished  tide-search
# 	Runtime:  26.387521028518677
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.5995681285858154
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44"
# 	Finished  percolator
# 	Runtime:  28.141402006149292
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04175877571105957
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.041316986083984375
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06821680068969727
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr44_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04910397529602051
#
# 	Runtime of sample:  55.331084966659546
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45"
# 	Finished  tide-search
# 	Runtime:  24.042948961257935
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.4464399814605713
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45"
# 	Finished  percolator
# 	Runtime:  25.709632873535156
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03399205207824707
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.03398394584655762
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04400300979614258
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr45_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.04334092140197754
#
# 	Runtime of sample:  50.3564989566803
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46"
# 	Finished  tide-search
# 	Runtime:  28.859060049057007
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.6104888916015625
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46"
# 	Finished  percolator
# 	Runtime:  29.706686973571777
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.044416189193725586
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.043840885162353516
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr46/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07321906089782715
#
# 	Running  sort-by-column
# ...
# 	Finished  percolator
# 	Runtime:  36.34086203575134
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0560297966003418
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05170798301696777
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06477808952331543
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr67_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.070281982421875
#
# 	Runtime of sample:  79.63261485099792
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68"
# 	Finished  tide-search
# 	Runtime:  39.98495411872864
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8332130908966064
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68"
# 	Finished  percolator
# 	Runtime:  36.82714605331421
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05677604675292969
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05380415916442871
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07131123542785645
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr68_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06996297836303711
#
# 	Runtime of sample:  77.90097212791443
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69"
# 	Finished  tide-search
# 	Runtime:  37.78254795074463
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8125009536743164
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69"
# 	Finished  percolator
# 	Runtime:  37.29868507385254
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05748701095581055
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05888795852661133
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07063794136047363
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr69_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07726407051086426
#
# 	Runtime of sample:  76.16142416000366
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70"
# 	Finished  tide-search
# 	Runtime:  43.47369599342346
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.8590559959411621
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70"
# 	Finished  percolator
# 	Runtime:  38.12519598007202
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.05814003944396973
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0579378604888916
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.06958699226379395
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr70_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07263493537902832
#
# 	Runtime of sample:  82.72021818161011
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71"
# 	Finished  tide-search
# 	Runtime:  77.03563499450684
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.3357179164886475
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71"
# 	Finished  percolator
# 	Runtime:  51.88467192649841
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07869100570678711
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0754859447479248
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09412693977355957
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr71_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.09643816947937012
#
# 	Runtime of sample:  130.6047990322113
#
# ***Running for sample:  ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72
#
# 	Running  tide-search
# 	 crux tide-search --compute-sp T --precursor-window 10 --precursor-window-type ppm ../data/ms2_data/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72.ms2 ../results/ref-index  --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72"
# 	Finished  tide-search
# 	Runtime:  69.10896182060242
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/tide-search.target.txt "xcorr score" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/tide-search.target.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  1.2675518989562988
#
# 	Running  percolator
# 	 crux percolator --test-fdr 0.05 --train-fdr 0.05 ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/tide-search.target.txt --output-dir "../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72"
# 	Finished  percolator
# 	Runtime:  49.24658679962158
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.peptides.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.0761418342590332
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.peptides.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72_percolator.target.peptides.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.07126617431640625
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.psms.txt "percolator q-value" > ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08718299865722656
#
# 	Running  sort-by-column
# 	 crux sort-by-column --column-type real --ascending T ../results/out_ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72/percolator.target.psms.txt "percolator q-value" > ../results/all_results/ElenaP_20141223_Hela_ctrl-perv-mit_stTiO2_TMT10_IPG25-37_10of15ul_fr72_percolator.target.psms.sort.txt
# 	Finished  sort-by-column
# 	Runtime:  0.08527493476867676
#
# 	Runtime of sample:  119.94740796089172
#
# Total runtime:  2942.882080078125
